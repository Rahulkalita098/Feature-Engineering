# %% [markdown]
# ### 1. What is a parameter?
#
# **Answer:** A parameter is a numerical value that describes a population characteristic, such as population mean or population variance.

# %% [markdown]
# ### 2. What is correlation?
#
# **Answer:** Correlation measures the strength and direction of the relationship between two variables.

# %% [markdown]
# ### 3. What does negative correlation mean?
#
# **Answer:** Negative correlation means that when one variable increases, the other decreases.

# %% [markdown]
# ### 4. Define Machine Learning. What are the main components in Machine Learning?
#
# **Answer:** Machine Learning is a field of AI where systems learn from data. Components include data, model, loss function, optimizer, evaluation.

# %% [markdown]
# ### 5. How does loss value help in determining whether the model is good or not?
#
# **Answer:** Loss value indicates how far predictions are from actual values. Lower loss means a better model.

# %% [markdown]
# ### 6. What are continuous and categorical variables?
#
# **Answer:** Continuous variables are numeric with infinite values; categorical variables represent groups or categories.

# %% [markdown]
# ### 7. How do we handle categorical variables in Machine Learning? What are the common techniques?
#
# **Answer:** Common methods: Label Encoding, One-Hot Encoding, Ordinal Encoding, Target Encoding.

# %% [markdown]
# ### 8. What do you mean by training and testing a dataset?
#
# **Answer:** Training dataset is used to train the model; testing dataset evaluates model performance.

# %% [markdown]
# ### 9. What is sklearn.preprocessing?
#
# **Answer:** sklearn.preprocessing contains tools for scaling, encoding, transforming data.

# %% [markdown]
# ### 10. What is a Test set?
#
# **Answer:** Test set is the portion of data used to evaluate model accuracy.

# %% [markdown]
# ### 11. How do we split data for model fitting (training and testing) in Python?
#
# **Answer:** In Python, we typically use train_test_split from sklearn.model_selection.

# %% [markdown]
# ### 12. How do you approach a Machine Learning problem?
#
# **Answer:** Steps: Understand problem, collect data, preprocess, EDA, feature engineering, model building, evaluation, deployment.

# %% [markdown]
# ### 13. Why do we have to perform EDA before fitting a model to the data?
#
# **Answer:** EDA helps detect patterns, missing values, correlations, outliers.

# %% [markdown]
# ### 14. What is correlation?
#
# **Answer:** Correlation measures relationship strength between variables.

# %% [markdown]
# ### 15. What does negative correlation mean?
#
# **Answer:** Negative correlation means inverse movement between variables.

# %% [markdown]
# ### 16. How can you find correlation between variables in Python?
#
# **Answer:** In Python, use df.corr() or seaborn heatmap.

# %% [markdown]
# ### 17. What is causation? Explain difference between correlation and causation with an example.
#
# **Answer:** Causation means one variable directly affects another. Correlation does not imply causation. Example: Ice cream sales correlate with drowning cases but do not cause them.

# %% [markdown]
# ### 18. What is an Optimizer? What are different types of optimizers? Explain each with an example.
#
# **Answer:** Optimizer updates model parameters based on loss gradient. Examples: SGD, Adam, RMSprop.

# %% [markdown]
# ### 19. What is sklearn.linear_model?
#
# **Answer:** sklearn.linear_model contains linear models like LinearRegression, LogisticRegression.

# %% [markdown]
# ### 20. What does model.fit() do? What arguments must be given?
#
# **Answer:** model.fit() trains the model and takes X (features) and y (labels).

# %% [markdown]
# ### 21. What does model.predict() do? What arguments must be given?
#
# **Answer:** model.predict() generates predictions from trained model and takes X (input data).

# %% [markdown]
# ### 22. What are continuous and categorical variables?
#
# **Answer:** Continuous variables: numeric; categorical: labels/groups.

# %% [markdown]
# ### 23. What is feature scaling? How does it help in Machine Learning?
#
# **Answer:** Feature scaling standardizes feature values, improving model performance.

# %% [markdown]
# ### 24. How do we perform scaling in Python?
#
# **Answer:** In Python: StandardScaler(), MinMaxScaler() from sklearn.preprocessing.

# %% [markdown]
# ### 25. What is sklearn.preprocessing?
#
# **Answer:** sklearn.preprocessing handles scaling and encoding.

# %% [markdown]
# ### 26. How do we split data for model fitting (training and testing) in Python?
#
# **Answer:** train_test_split(X, y, test_size=0.2).

# %% [markdown]
# ### 27. Explain data encoding?
#
# **Answer:** Data encoding transforms categories into numeric form.
